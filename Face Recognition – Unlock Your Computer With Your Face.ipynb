# %% [markdown]
# ## Face Recognition – Unlock Your Computer With Your Face!

# %% [markdown]
# ### Step 1 - Create Training Data

# %%
import cv2
import numpy as np

# Load HAAR face classifier
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Load functions
def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

# Initialize Webcam
cap = cv2.VideoCapture(0)
count = 0

# Collect 100 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (200, 200))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Save file in specified directory with unique name
        file_name_path = 'C:/Users/Admin/Desktop/unlock_by_face/faces/user/' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Face  found")
        pass

    if cv2.waitKey(1) == 13 or count == 100: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Collecting Samples Complete")

# %%
#CREATING DATABSE FOR 2 USER

# %%
import cv2
import numpy as np

# Load HAAR face classifier
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Load functions
def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

# Initialize Webcam
cap = cv2.VideoCapture(0)
count = 0

# Collect 100 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (200, 200))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Save file in specified directory with unique name
        file_name_path_1= 'C:/Users/Admin/Desktop/unlock_by_face/faces/user1/' + str(count) + '.jpg'
        cv2.imwrite(file_name_path_1, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Face  found")
        pass

    if cv2.waitKey(1) == 13 or count == 100: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Collecting Samples Complete")

# %%
#Dataset 3q

# %%
import cv2
import numpy as np

# Load HAAR face classifier
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Load functions
def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

# Initialize Webcam
cap = cv2.VideoCapture(0)
count = 0

# Collect 100 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (200, 200))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Save file in specified directory with unique name
        file_name_path = 'C:/Users/Admin/Desktop/unlock_by_face/faces/user2/' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Face  found")
        pass

    if cv2.waitKey(1) == 13 or count == 100: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Collecting Samples Complete")

# %%
#Dataset 4

# %%
import cv2
import numpy as np

# Load HAAR face classifier
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Load functions
def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

# Initialize Webcam
cap = cv2.VideoCapture(0)
count = 0

# Collect 100 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (200, 200))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Save file in specified directory with unique name
        file_name_path = 'C:/Users/Admin/Desktop/unlock_by_face/faces/user3/' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Face  found")
        pass

    if cv2.waitKey(1) == 13 or count == 100: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Collecting Samples Complete")

# %% [markdown]
# ### Step 2 - Train Model

# %%
cap.release()

# %%
#TRAINING MODEL FOR USER

# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join

# Get the training data we previously made
data_path_2 = 'C:/Users/Admin/Desktop/unlock_by_face/faces/user/'
onlyfiles_2 = [f for f in listdir(data_path_2) if isfile(join(data_path_2, f))]

# Create arrays for training data and labels
Training_Data_2, Labels_2 = [], []

# Open training images in our datapath
# Create a numpy array for training data
for i, files in enumerate(onlyfiles_2):
    image_path_2 = data_path_2 + onlyfiles_2[i]
    images_2 = cv2.imread(image_path_2, cv2.IMREAD_GRAYSCALE)
    Training_Data_2.append(np.asarray(images_2, dtype=np.uint8))
    Labels_2.append(i)

# Create a numpy array for both training data and labels
Labels_2 = np.asarray(Labels_2, dtype=np.int32)

# Initialize facial recognizer
# model = cv2.face.createLBPHFaceRecognizer()
# NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()
# pip install opencv-contrib-python
# model = cv2.createLBPHFaceRecognizer()

abhay_model  = cv2.face_LBPHFaceRecognizer.create()
# Let's train our model 
abhay_model.train(np.asarray(Training_Data_2), np.asarray(Labels_2))
print("Model trained sucessefully")
# Out:
# Model trained sucessefully

# %%
#TRAINING MODEL FOR USER 2

# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join

# Get the training data we previously made
data_path_1= 'C:/Users/Admin/Desktop/unlock_by_face/faces/user1/'
onlyfiles_1 = [f for f in listdir(data_path_1) if isfile(join(data_path_1, f))]

# Create arrays for training data and labels
Training_Data_1, Labels_1 = [], []

# Open training images in our datapath
# Create a numpy array for training data
for i, files in enumerate(onlyfiles_1):
    image_path_1 = data_path_1 + onlyfiles_1[i]
    images_1 = cv2.imread(image_path_1, cv2.IMREAD_GRAYSCALE)
    Training_Data_1.append(np.asarray(images_1, dtype=np.uint8))
    Labels_1.append(i)

# Create a numpy array for both training data and labels
Labels_1 = np.asarray(Labels_1, dtype=np.int32)

# Initialize facial recognizer
# model = cv2.face.createLBPHFaceRecognizer()
# NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()
# pip install opencv-contrib-python
# model = cv2.createLBPHFaceRecognizer()

shivi_model  = cv2.face_LBPHFaceRecognizer.create()
# Let's train our model 
shivi_model.train(np.asarray(Training_Data_1), np.asarray(Labels_1))
print("Model trained sucessefully")
# Out:
# Model trained sucessefully

# %%
#model 3

# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join

# Get the training data we previously made
data_path_3= 'C:/Users/Admin/Desktop/unlock_by_face/faces/user2/'
onlyfiles_3 = [f for f in listdir(data_path_3) if isfile(join(data_path_3, f))]

# Create arrays for training data and labels
Training_Data_3, Labels_3 = [], []

# Open training images in our datapath
# Create a numpy array for training data
for i, files in enumerate(onlyfiles_3):
    image_path_3 = data_path_3 + onlyfiles_3[i]
    images_3 = cv2.imread(image_path_3, cv2.IMREAD_GRAYSCALE)
    Training_Data_3.append(np.asarray(images_3, dtype=np.uint8))
    Labels_3.append(i)

# Create a numpy array for both training data and labels
Labels_3 = np.asarray(Labels_3, dtype=np.int32)

# Initialize facial recognizer
# model = cv2.face.createLBPHFaceRecognizer()
# NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()
# pip install opencv-contrib-python
# model = cv2.createLBPHFaceRecognizer()

aakash_model  = cv2.face_LBPHFaceRecognizer.create()
# Let's train our model 
aakash_model.train(np.asarray(Training_Data_3), np.asarray(Labels_3))
print("Model trained sucessefully")
# Out:
# Model trained sucessefully

# %%
#4 dataset model

# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join

# Get the training data we previously made
data_path_4= 'C:/Users/Admin/Desktop/unlock_by_face/faces/user3/'
onlyfiles_4 = [f for f in listdir(data_path_4) if isfile(join(data_path_4, f))]

# Create arrays for training data and labels
Training_Data_4, Labels_4 = [], []

# Open training images in our datapath
# Create a numpy array for training data
for i, files in enumerate(onlyfiles_4):
    image_path_4 = data_path_4 + onlyfiles_4[i]
    images_4 = cv2.imread(image_path_4, cv2.IMREAD_GRAYSCALE)
    Training_Data_4.append(np.asarray(images_4, dtype=np.uint8))
    Labels_4.append(i)

# Create a numpy array for both training data and labels
Labels_4 = np.asarray(Labels_4, dtype=np.int32)

# Initialize facial recognizer
# model = cv2.face.createLBPHFaceRecognizer()
# NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()
# pip install opencv-contrib-python
# model = cv2.createLBPHFaceRecognizer()

adarsh_model  = cv2.face_LBPHFaceRecognizer.create()
# Let's train our model 
adarsh_model.train(np.asarray(Training_Data_4), np.asarray(Labels_4))
print("Model trained sucessefully")
# Out:
# Model trained sucessefully

# %% [markdown]
# ### Step 3 - Run Our Facial Recognition

# %%
import cv2
import numpy as np
import os
import pywhatkit
import smtplib
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
from email.mime.multipart import MIMEMultipart
from email.message import EmailMessage


face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []
    
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi


# Open Webcam
cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()
    
    image, face = face_detector(frame)
    
    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        results = abhay_model.predict(face)
        results_1 = shivi_model.predict(face)
        results_2 =aakash_model.predict(face)
        results_3 = adarsh_model.predict(face)
        
        
        # harry_model.predict(face  
        if results[1] < 500:
            confidence = int( 100 * (1 - (results[1])/400) )
            display_string = str(confidence) + '% Confident it is User'
            
            cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
        
        if confidence > 80:
            cv2.putText(image, "Hey Abhay", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
            Sender = "abhay.desai012@gmail.com"
            Reciever = "abhay.desai0001@gmail.com"
            Password = "saafbohxfwjqdyal"
            mes = EmailMessage()
            mes['Subject'] = "SOMEONE INSIDE " 
            mes['From'] = Sender                 
            mes['To'] = Reciever                  
            mes.set_content('this is face of Abhay') 
            #mes.add_attachment(image_data, maintype='image', subtype=image_type)
            with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
                    smtp.login(Sender, Password)              
                    smtp.send_message(mes) 
            break
         
         
        else:
            
            cv2.putText(image, "I dont know, how r u", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )
            
        if results_1[1] < 500:
            confidence_1 = int( 100 * (1 - (results_1[1])/400) )
            display_string_1= str(confidence_1) + '% Confident it is User'
            
            cv2.putText(image, display_string_1, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
        
        if confidence_1 > 80:
            cv2.putText(image, "Hey sp", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
            print("terraform time")
            #os.system("cd C:\terraform file")
           # os.system("start cd c:/terraform file ")
            os.system("start terraform init")
            print("done1")
            os.system("start terraform validate")
            print("done2")
            #os.system("start terraform plan")
            #print("started")
            os.system("start terraform apply --auto-approve")
            print("done")
            break
         
         
        else:
            
            cv2.putText(image, "I dont know, how r u", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )
            
        if results_2[1] < 500:
            confidence_2 = int( 100 * (1 - (results_2[1])/400) )
            display_string_2 = str(confidence_2) + '% Confident it is User'
            
            cv2.putText(image, display_string_2, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
        
        if confidence_2 > 80:
            cv2.putText(image, "Hey Aakash", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
            pywhatkit.sendwhatmsg('+917027097933', 'Hiii bro , how are you doing .. ?.',21,43)
            break
         
         
        else:
            
            cv2.putText(image, "I dont know, how r u", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )
        
        if results_3[1] < 500:
            confidence_3 = int( 100 * (1 - (results_3[1])/400) )
            display_string_3= str(confidence_3) + '% Confident it is User'
            
            cv2.putText(image, display_string_3, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
        
        if confidence_3 > 90:
            cv2.putText(image, "Hey Adarsh", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
            from twilio.rest import Client
            account_sid = "A*****************************"
            auth_token = "b******************************"
            client = Client(account_sid, auth_token)
            message = client.messages.create( body="SOMEONE INSIDE", from_='+19378136847', to='+919834843396') 
            print(message.sid)
            break
         
         
        else:
            
            cv2.putText(image, "I dont know, how r u", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )
         

    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "looking for face", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass
        
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        o
cap.release()
cv2.destroyAllWindows()
# Out:
# <>:19: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:19: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-12-42404fa08360>:19: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# SM3f17e764ae7a4d798a649923fae8367e
